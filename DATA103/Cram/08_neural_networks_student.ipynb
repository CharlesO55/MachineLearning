# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, precision_score, f1_score, recall_score
from sklearn.model_selection import GridSearchCV


import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
sns.set_palette('Set2')
sns.color_palette('Set2')
dlsu_green = "#117a65ff"

# %%
wine_df = pd.read_csv("Data/winequality-red.csv")
wine_df['quality_label'] = wine_df.quality.apply(lambda x: 1 if x >= 7 else 0)

# %%
X = wine_df.loc[:, 'fixed acidity': 'alcohol']
y = wine_df['quality_label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %% [markdown]
# ## Hyperparameters for Neural Networks
#
# - hidden_layer_sizes - accespts tuples, the length of the tuple represents the number of hidden layers while the numeric value represents the number of nodes for each hidden layer. Example (13,13,13) means that you have 3 hidden layers with 13 nodes for each layer.
# - alpha - regularization parameter, larger alpha values would reduce weights greatly while smaller values reduce the weights a bit
# - learning_rate - algorithm used to adjust the learning rate, constant keeps using the same learning rate throughout the training while adapative keeps the learning rate constant while loss keeps decreasing. If loss does not decrease for 2 iterations the learning rate is divided by 5
# - learning_rate_init - the initial learning rate to use which controls the step size in changing the weights
#
# ## Stopping Criterions
#
# - max_iter - # of iterations to run the training
# - tol - When the loss or score is not improving by at least the tol value convergence is considered to be reached and training stops.

# %%
mlp = MLPClassifier(hidden_layer_sizes=(13,13,13),max_iter=500)
mlp.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(13, 13, 13), max_iter=500)

# %%
y_pred = mlp.predict(X_test)
print(f"Acc:{mlp.score(X_test, y_test)}")
print(f"Precision:{precision_score(y_test, y_pred)}")
print(f"Recall:{recall_score(y_test, y_pred)}")
print(f"F1-Score:{f1_score(y_test, y_pred)}")
# Out:
# Acc:0.85
# Precision:0.47058823529411764
# Recall:0.1702127659574468
# F1-Score:0.25

# %% [markdown]
# ### Hyperparameter Optimization

# %%
param_grid = {
    'hidden_layer_sizes': [(50,), (13,13,13), (13,10,5),(50,50,50),(25,25,25,25,25)],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
    'learning_rate_init': [0.01, 0.00001, 0.1]
}
mlp = MLPClassifier()
clf = GridSearchCV(mlp, param_grid, n_jobs=-1, cv=5)
clf.fit(X_train, y_train) # X is train samples and y is the corresponding labels
# Out:
# GridSearchCV(cv=5, estimator=MLPClassifier(), n_jobs=-1,
#              param_grid={'alpha': [0.0001, 0.05],
#                          'hidden_layer_sizes': [(50,), (13, 13, 13),
#                                                 (13, 10, 5), (50, 50, 50),
#                                                 (25, 25, 25, 25, 25)],
#                          'learning_rate': ['constant', 'adaptive'],
#                          'learning_rate_init': [0.01, 1e-05, 0.1]})

# %%
clf.best_estimator_
# Out:
# MLPClassifier(hidden_layer_sizes=(13, 13, 13), learning_rate_init=0.01)

# %%
best_clf = clf.best_estimator_
y_pred = best_clf.predict(X_test)
print(f"Acc:{best_clf.score(X_test, y_test)}")
print(f"Precision:{precision_score(y_test, y_pred)}")
print(f"Recall:{recall_score(y_test, y_pred)}")
print(f"F1-Score:{f1_score(y_test, y_pred)}")
# Out:
# Acc:0.859375
# Precision:0.55
# Recall:0.23404255319148937
# F1-Score:0.3283582089552239

# %%
result_df = pd.DataFrame.from_dict(clf.cv_results_, orient='columns')
result_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.336562      0.050873         0.003207        0.000502      0.0001
# 1        0.826658      0.025343         0.003389        0.000490      0.0001
# 2        0.246094      0.090872         0.002894        0.000660      0.0001
# 3        0.278503      0.084018         0.002804        0.000405      0.0001
# 4        0.829809      0.022422         0.002400        0.000482      0.0001
# 5        0.293087      0.085694         0.002917        0.000199      0.0001
# 6        0.464019      0.098893         0.002897        0.000494      0.0001
# 7        1.091788      0.013932         0.003199        0.000396      0.0001
# 8        0.270084      0.119595         0.002790        0.000399      0.0001
# 5                     (50,)            adaptive                      0.1
# 6              (13, 13, 13)            constant                     0.01
# 7              (13, 13, 13)            constant                  0.00001
# 8              (13, 13, 13)            constant                      0.1
# 9              (13, 13, 13)            adaptive                     0.01
# 10             (13, 13, 13)            adaptive                  0.00001
# 11             (13, 13, 13)            adaptive                      0.1
# 12              (13, 10, 5)            constant                     0.01
# 13              (13, 10, 5)            constant                  0.00001
# 14              (13, 10, 5)            constant                      0.1
# 15              (13, 10, 5)            adaptive                     0.01
# 16              (13, 10, 5)            adaptive                  0.00001
# 17              (13, 10, 5)            adaptive                      0.1
# 18             (50, 50, 50)            constant                     0.01
# 19             (50, 50, 50)            constant                  0.00001
# 20             (50, 50, 50)            constant                      0.1
# 21             (50, 50, 50)            adaptive                     0.01
# 22             (50, 50, 50)            adaptive                  0.00001
# 23             (50, 50, 50)            adaptive                      0.1
# 24     (25, 25, 25, 25, 25)            constant                     0.01
# 25     (25, 25, 25, 25, 25)            constant                  0.00001
# 26     (25, 25, 25, 25, 25)            constant                      0.1
# 27     (25, 25, 25, 25, 25)            adaptive                     0.01
# 28     (25, 25, 25, 25, 25)            adaptive                  0.00001
# 29     (25, 25, 25, 25, 25)            adaptive                      0.1
# 30                    (50,)            constant                     0.01
# 31                    (50,)            constant                  0.00001
# 32                    (50,)            constant                      0.1
# 33                    (50,)            adaptive                     0.01
# 34                    (50,)            adaptive                  0.00001
# 35                    (50,)            adaptive                      0.1
# 36             (13, 13, 13)            constant                     0.01
# 37             (13, 13, 13)            constant                  0.00001
# 38             (13, 13, 13)            constant                      0.1
# 39             (13, 13, 13)            adaptive                     0.01
# 40             (13, 13, 13)            adaptive                  0.00001
# 41             (13, 13, 13)            adaptive                      0.1
# 42              (13, 10, 5)            constant                     0.01
# 43              (13, 10, 5)            constant                  0.00001
# 44              (13, 10, 5)            constant                      0.1
# 45              (13, 10, 5)            adaptive                     0.01
# 46              (13, 10, 5)            adaptive                  0.00001
# 47              (13, 10, 5)            adaptive                      0.1
# 48             (50, 50, 50)            constant                     0.01
# 49             (50, 50, 50)            constant                  0.00001
# 50             (50, 50, 50)            constant                      0.1
# 51             (50, 50, 50)            adaptive                     0.01
# 52             (50, 50, 50)            adaptive                  0.00001
# 53             (50, 50, 50)            adaptive                      0.1
# 54     (25, 25, 25, 25, 25)            constant                     0.01
# 55     (25, 25, 25, 25, 25)            constant                  0.00001
# 56     (25, 25, 25, 25, 25)            constant                      0.1
# 57     (25, 25, 25, 25, 25)            adaptive                     0.01
# 58     (25, 25, 25, 25, 25)            adaptive                  0.00001
# 59     (25, 25, 25, 25, 25)            adaptive                      0.1
#
#                                                params  split0_test_score  \
# 0   {'alpha': 0.0001, 'hidden_layer_sizes': (50,),...           0.867188
# 1   {'alpha': 0.0001, 'hidden_layer_sizes': (50,),...           0.824219
# 2   {'alpha': 0.0001, 'hidden_layer_sizes': (50,),...           0.867188
# 3   {'alpha': 0.0001, 'hidden_layer_sizes': (50,),...           0.839844
# 4   {'alpha': 0.0001, 'hidden_layer_sizes': (50,),...           0.855469
# 5   {'alpha': 0.0001, 'hidden_layer_sizes': (50,),...           0.878906
# 6   {'alpha': 0.0001, 'hidden_layer_sizes': (13, 1...           0.867188
# 7   {'alpha': 0.0001, 'hidden_layer_sizes': (13, 1...           0.132812
# 8   {'alpha': 0.0001, 'hidden_layer_sizes': (13, 1...           0.867188
# 9   {'alpha': 0.0001, 'hidden_layer_sizes': (13, 1...           0.863281
# 10  {'alpha': 0.0001, 'hidden_layer_sizes': (13, 1...           0.132812
# 11  {'alpha': 0.0001, 'hidden_layer_sizes': (13, 1...           0.867188
# 12  {'alpha': 0.0001, 'hidden_layer_sizes': (13, 1...           0.855469
# 13  {'alpha': 0.0001, 'hidden_layer_sizes': (13, 1...           0.867188
# 14  {'alpha': 0.0001, 'hidden_layer_sizes': (13, 1...           0.867188
# 15  {'alpha': 0.0001, 'hidden_layer_sizes': (13, 1...           0.863281
# 16  {'alpha': 0.0001, 'hidden_layer_sizes': (13, 1...           0.859375
# 17  {'alpha': 0.0001, 'hidden_layer_sizes': (13, 1...           0.867188
# 18  {'alpha': 0.0001, 'hidden_layer_sizes': (50, 5...           0.863281
# 19  {'alpha': 0.0001, 'hidden_layer_sizes': (50, 5...           0.867188
# 20  {'alpha': 0.0001, 'hidden_layer_sizes': (50, 5...           0.867188
# 21  {'alpha': 0.0001, 'hidden_layer_sizes': (50, 5...           0.867188
# 22  {'alpha': 0.0001, 'hidden_layer_sizes': (50, 5...           0.867188
# 23  {'alpha': 0.0001, 'hidden_layer_sizes': (50, 5...           0.867188
# 24  {'alpha': 0.0001, 'hidden_layer_sizes': (25, 2...           0.859375
# 25  {'alpha': 0.0001, 'hidden_layer_sizes': (25, 2...           0.867188
# 26  {'alpha': 0.0001, 'hidden_layer_sizes': (25, 2...           0.867188
# 27  {'alpha': 0.0001, 'hidden_layer_sizes': (25, 2...           0.863281
# 28  {'alpha': 0.0001, 'hidden_layer_sizes': (25, 2...           0.867188
# 29  {'alpha': 0.0001, 'hidden_layer_sizes': (25, 2...           0.867188
# 30  {'alpha': 0.05, 'hidden_layer_sizes': (50,), '...           0.863281
# 31  {'alpha': 0.05, 'hidden_layer_sizes': (50,), '...           0.152344
# 32  {'alpha': 0.05, 'hidden_layer_sizes': (50,), '...           0.871094
# 33  {'alpha': 0.05, 'hidden_layer_sizes': (50,), '...           0.855469
# 34  {'alpha': 0.05, 'hidden_layer_sizes': (50,), '...           0.132812
# 35  {'alpha': 0.05, 'hidden_layer_sizes': (50,), '...           0.796875
# 36  {'alpha': 0.05, 'hidden_layer_sizes': (13, 13,...           0.867188
# 37  {'alpha': 0.05, 'hidden_layer_sizes': (13, 13,...           0.867188
# 38  {'alpha': 0.05, 'hidden_layer_sizes': (13, 13,...           0.867188
# 39  {'alpha': 0.05, 'hidden_layer_sizes': (13, 13,...           0.847656
# 40  {'alpha': 0.05, 'hidden_layer_sizes': (13, 13,...           0.132812
# 41  {'alpha': 0.05, 'hidden_layer_sizes': (13, 13,...           0.867188
# 42  {'alpha': 0.05, 'hidden_layer_sizes': (13, 10,...           0.855469
# 43  {'alpha': 0.05, 'hidden_layer_sizes': (13, 10,...           0.867188
# 44  {'alpha': 0.05, 'hidden_layer_sizes': (13, 10,...           0.867188
# 45  {'alpha': 0.05, 'hidden_layer_sizes': (13, 10,...           0.867188
# 46  {'alpha': 0.05, 'hidden_layer_sizes': (13, 10,...           0.820312
# 47  {'alpha': 0.05, 'hidden_layer_sizes': (13, 10,...           0.867188
# 48  {'alpha': 0.05, 'hidden_layer_sizes': (50, 50,...           0.875000
# 49  {'alpha': 0.05, 'hidden_layer_sizes': (50, 50,...           0.871094
# 50  {'alpha': 0.05, 'hidden_layer_sizes': (50, 50,...           0.859375
# 51  {'alpha': 0.05, 'hidden_layer_sizes': (50, 50,...           0.882812
# 52  {'alpha': 0.05, 'hidden_layer_sizes': (50, 50,...           0.867188
# 53  {'alpha': 0.05, 'hidden_layer_sizes': (50, 50,...           0.867188
# 10           0.827451         0.563146        0.348377               59
# 11           0.866667         0.867083        0.000208               13
# 12           0.866667         0.863958        0.004488               39
# 13           0.866667         0.719427        0.295260               52
# 14           0.866667         0.867083        0.000208               13
# 15           0.866667         0.867083        0.006540               13
# 16           0.423529         0.686268        0.158962               54
# 17           0.866667         0.867083        0.000208               13
# 18           0.878431         0.864749        0.011095               37
# 19           0.866667         0.867083        0.000208               13
# 20           0.866667         0.867083        0.000208               13
# 21           0.874510         0.870996        0.003388                6
# 22           0.866667         0.863958        0.006201               39
# 23           0.866667         0.867083        0.000208               13
# 24           0.878431         0.863186        0.012480               41
# 25           0.866667         0.838177        0.055826               46
# 26           0.866667         0.867083        0.000208               13
# 27           0.874510         0.864746        0.007526               38
# 28           0.866667         0.867083        0.000208               13
# 29           0.866667         0.867083        0.000208               13
# 30           0.819608         0.852203        0.028693               44
# 31           0.203922         0.590003        0.336698               57
# 32           0.866667         0.867083        0.002479               13
# 33           0.870588         0.865524        0.005755               35
# 34           0.592157         0.648119        0.275159               55
# 35           0.858824         0.851452        0.027480               45
# 36           0.878431         0.869436        0.016813                9
# 37           0.866667         0.810052        0.114011               48
# 38           0.866667         0.867083        0.000208               13
# 39           0.870588         0.861618        0.021579               43
# 40           0.325490         0.419004        0.290112               60
# 41           0.866667         0.867083        0.000208               13
# 42           0.866667         0.871771        0.010645                5
# 43           0.858824         0.719421        0.293332               53
# 44           0.866667         0.867083        0.000208               13
# 45           0.866667         0.870208        0.006772                8
# 46           0.866667         0.565521        0.350538               58
# 47           0.866667         0.867083        0.000208               13
# 48           0.870588         0.867868        0.005125               10
# 49           0.866667         0.867083        0.002479               13
# 50           0.866667         0.865521        0.003080               36
# 51           0.862745         0.874893        0.008349                2
# 52           0.866667         0.867083        0.000208               13
# 53           0.866667         0.867083        0.000208               13
# 54           0.874510         0.867089        0.012779               11
# 55           0.866667         0.867083        0.000208               13
# 56           0.866667         0.867083        0.000208               13
# 57           0.870588         0.867086        0.005989               12
# 58           0.866667         0.799115        0.135886               49
# 59           0.866667         0.867083        0.000208               13

# %%
result_df.groupby('param_hidden_layer_sizes').mean_test_score.max()
# Out:
# param_hidden_layer_sizes
# (13, 10, 5)             0.871771
# (13, 13, 13)            0.874911
# (25, 25, 25, 25, 25)    0.867089
# (50,)                   0.873333
# (50, 50, 50)            0.874893
# Name: mean_test_score, dtype: float64

# %%
fig, axes = plt.subplots(figsize=(15,15), nrows=2, ncols=2)
sns.violinplot(data=result_df, x='param_learning_rate', y='mean_test_score', ax=axes[0][0])
sns.boxplot(data=result_df, x='param_hidden_layer_sizes', y='mean_test_score', ax=axes[0][1])
sns.scatterplot(data=result_df, x='param_learning_rate_init', y='mean_test_score', ax=axes[1][0])
sns.scatterplot(data=result_df, x='param_alpha', y='mean_test_score', ax=axes[1][1])

axes[0][0].set_ylim(0.4,1)
axes[0][1].set_ylim(0.4,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 fig, axes = plt.subplots(figsize=(15,15), nrows=2, ncols=2)
#       2 sns.violinplot(data=result_df, x='param_learning_rate', y='mean_test_score', ax=axes[0][0])
# ----> 3 sns.boxplot(data=result_df, x='param_hidden_layer_sizes', y='mean_test_score', ax=axes[0][1])
#       4 sns.scatterplot(data=result_df, x='param_learning_rate_init', y='mean_test_score', ax=axes[1][0])
#       5 sns.scatterplot(data=result_df, x='param_alpha', y='mean_test_score', ax=axes[1][1])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1602, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1599     dodge = p._dodge_needed()
#    1601 if p.var_types.get(p.orient) == "categorical" or not native_scale:
# -> 1602     p.scale_categorical(p.orient, order=order, formatter=formatter)
#    1604 p._attach(ax, log_scale=log_scale)
#    1606 # Deprecations to remove in v0.14.0.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:1430, in VectorPlotter.scale_categorical(self, axis, order, formatter)
#    1425 # Get the initial categorical order, which we do before string
#    1426 # conversion to respect the original types of the order list.
#    1427 # Track whether the order is given explicitly so that we can know
#    1428 # whether or not to use the order constructed here downstream
#    1429 self._var_ordered[axis] = order is not None or cat_data.dtype.name == "category"
# -> 1430 order = pd.Index(categorical_order(cat_data, order), name=axis)
#    1432 # Then convert data to strings. This is because in matplotlib,
#    1433 # "categorical" data really mean "string" data, so doing this artists
#    1434 # will be drawn on the categorical axis with a fixed scale.
#    1435 # TODO implement formatter here; check that it returns strings?
#    1436 if formatter is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:543, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     538     if data and all(isinstance(e, tuple) for e in data):
#     539         # we must be all tuples, otherwise don't construct
#     540         # 10697
#     541         from pandas.core.indexes.multi import MultiIndex
# --> 543         return MultiIndex.from_tuples(data, names=name)
#     544 # other iterable of some kind
#     546 if not isinstance(data, (list, tuple)):
#     547     # we allow set/frozenset, which Series/sanitize_array does not, so
#     548     #  cast to list here
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:220, in names_compat.<locals>.new_meth(self_or_cls, *args, **kwargs)
#     217 if "name" in kwargs:
#     218     kwargs["names"] = kwargs.pop("name")
# --> 220 return meth(self_or_cls, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:622, in MultiIndex.from_tuples(cls, tuples, sortorder, names)
#     619     arrs = zip(*tuples)
#     620     arrays = cast(list[Sequence[Hashable]], arrs)
# --> 622 return cls.from_arrays(arrays, sortorder=sortorder, names=names)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:535, in MultiIndex.from_arrays(cls, arrays, sortorder, names)
#     532 if names is lib.no_default:
#     533     names = [getattr(arr, "name", None) for arr in arrays]
# --> 535 return cls(
#     536     levels=levels,
#     537     codes=codes,
#     538     sortorder=sortorder,
#     539     names=names,
#     540     verify_integrity=False,
#     541 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:354, in MultiIndex.__new__(cls, levels, codes, sortorder, names, dtype, copy, name, verify_integrity)
#     351 result._names = [None] * len(levels)
#     352 if names is not None:
#     353     # handles name validation
# --> 354     result._set_names(names)
#     356 if sortorder is not None:
#     357     result.sortorder = int(sortorder)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:1480, in MultiIndex._set_names(self, names, level, validate)
#    1477 # GH 15110
#    1478 # Don't allow a single string for names in a MultiIndex
#    1479 if names is not None and not is_list_like(names):
# -> 1480     raise ValueError("Names should be list-like for a MultiIndex")
#    1481 names = list(names)
#    1483 if validate:
#
# ValueError: Names should be list-like for a MultiIndex

# %% [markdown]
# ## Model Explainability using SHAP

# %%
import shap
shap.initjs()

explainer = shap.Explainer(best_clf.predict, X_train)
shap_values = explainer(X_test)
shap.plots.beeswarm(shap_values)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# PermutationExplainer explainer: 321it [00:22,  9.59it/s]

# %%
# Our group wanted to share additional code, if it's alright.

# feature importance
shap.plots.bar(shap_values.abs.mean(0))

# explanation for random single sample
import numpy as np

rng = np.random.default_rng(seed=42)
random_idx = rng.integers(low=0, high=X_test.shape[0])

shap.plots.waterfall(shap.Explanation(
    base_values=shap_values[0][0].base_values,
    values=shap_values[0].values,
    feature_names=X_test.columns,
    data=X_test.iloc[random_idx]
))
